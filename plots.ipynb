# %%
import matplotlib.pyplot as plt
import numpy as np
# times = [2530.671578645706, 2481.2810611724854, 2363.11671395, 2212.3679, 1889.838, 1406.64813251, 804.358756066, 536.878043811, 282.242906888, 176.985950152,137.00533684]
times = [ 198.42453320821124, 149.35919284820557, 129.23632740974426, 125.47183632850647, 119.9650502204895,
#          112.3575896024704, 95.82455039024353, 97.27736592292786, 118.03866684436798, 118.73517433802286, 127.77981106440226]
N = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# times = [2530.671578645706, 2481.2810611724854, 2212.3679, 2363.11671395, 1889.838, 1406.64813251]
# N = [1, 2, 4, 16, 32]

fig = plt.figure(figsize=(24, 12))
ax = fig.add_subplot(222)
ax.plot(N,times, color = 'blue')
ax.set_xlabel('Window Size(N)', fontsize=10)
ax.set_ylabel('Delay(Sec)', fontsize='medium')
plt.xscale('log',basex=2)
plt.xticks(N)
# Out:
# ([<matplotlib.axis.XTick at 0x1517df8d780>,
# ...
#  <a list of 11 Text xticklabel objects>)

# %%
MSS_times = [1294.72603721, 384.470335366,238.49037726720173, 132.97656218210856, 105.95022122065226, 90.83149353663126, 86.1715054512024, 63.20166190465291, 55.24916330973308, 48.62167596817017]
MSS = range(100,1100,100)

fig = plt.figure(figsize=(24, 12))
ax = fig.add_subplot(222)
ax.plot(MSS,MSS_times, color = 'blue')
ax.set_xlabel('MSS', fontsize=10)
ax.set_ylabel('Delay(Sec)', fontsize='medium')
# plt.xscale('log',basex=2)
plt.xticks(MSS)
# Out:
# ([<matplotlib.axis.XTick at 0x151006c4780>,
# ...
#  <a list of 10 Text xticklabel objects>)

# %%
prob_times = [16.286348700523376, 37.075075507164, 77.5709193944931, 82.83797085285187, 117.88293600082397, 137.1906304359436, 140.03565311431885
             , 160.6388783454895, 197.4742341041565, 227.70332515239716]
prob = [x * 0.01 for x in range(1, 11)]
fig = plt.figure(figsize=(24, 12))
ax = fig.add_subplot(222)
ax.plot(prob,prob_times, color = 'blue')
ax.set_xlabel('Loss Probability', fontsize=10)
ax.set_ylabel('Delay(Sec)', fontsize='medium')
# plt.xscale('log',basex=2)
plt.xticks(prob)
# Out:
# ([<matplotlib.axis.XTick at 0x15100eab128>,
# ...
#  <a list of 10 Text xticklabel objects>)

# %%
# times = [2530.671578645706, 2481.2810611724854, 2363.11671395, 2212.3679, 1889.838, 1406.64813251, 804.358756066, 536.878043811, 282.242906888, 176.985950152,137.00533684]
# times = [ 198.42453320821124, 149.35919284820557, 129.23632740974426, 125.47183632850647, 119.9650502204895,
#          112.3575896024704, 95.82455039024353, 97.27736592292786, 118.03866684436798, 118.73517433802286, 127.77981106440226]
times_dict = {64: 97.59761651357016, 32: 89.39863284428915, 2: 97.73722728093466, 4: 73.5883641242981, 1024: 73.31258217493694, 8: 116.66250626246133, 128: 78.68379990259807, 256: 70.73959271113078, 16: 78.8048259417216, 512: 84.09024635950723}
times = []
for i in sorted (times_dict) : 
    times.append(times_dict[i]) 
N = [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# times = [2530.671578645706, 2481.2810611724854, 2212.3679, 2363.11671395, 1889.838, 1406.64813251]
# N = [1, 2, 4, 16, 32]

fig = plt.figure(figsize=(24, 12))
ax = fig.add_subplot(222)
ax.plot(N,times, color = 'blue')
ax.set_xlabel('Window Size(N)', fontsize=10)
ax.set_ylabel('Delay(Sec)', fontsize='medium')
plt.xscale('log',basex=2)
plt.xticks(N)
# Out:
# ([<matplotlib.axis.XTick at 0x1517deab978>,
# ...
#  <a list of 10 Text xticklabel objects>)
